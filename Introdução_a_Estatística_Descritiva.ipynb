# %% [markdown]
# <a href="https://colab.research.google.com/github/chepanskierica/-rica-/blob/main/Introdu%C3%A7%C3%A3o_a_Estat%C3%ADstica_Descritiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr 
import numpy as np

# %% [markdown]
# # Dados

# %%
dados=[53.0 ,70.2 ,84.3 ,69.5 ,77.8 ,87.5 ,53.4 ,82.5 ,67.3 ,54.1 ,70.5 ,71.4 ,95.4 ,51.1 ,74.4 ,55.7 ,63.5 ,85.8 ,53.5 ,64.3 ,82.7 ,78.5 ,55.7 ,69.1 ,72.3 ,59.5 ,55.3 ,73.0 ,52.4 ,50.7]

# %% [markdown]
# ## A média

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.Series(dados).mean()
# Out:
# 67.81333333333333

# %% [markdown]
# ## A mediana

# %%
pd.Series(dados).median()
# Out:
# 69.3

# %% [markdown]
# ## Desvio Padrão

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.Series(dados).std()
# Out:
# 12.72536791239244

# %%
pd.Series(dados).mode()
# Out:
# 0    55.7
# dtype: float64

# %% [markdown]
# ## **A Variância**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.Series(dados).var()
# Out:
# 161.93498850574713

# %% [markdown]
# # **Resumo**

# %%
pd.Series(dados).describe()
# Out:
# count    30.000000
# mean     67.813333
# std      12.725368
# min      50.700000
# 25%      55.400000
# 50%      69.300000
# 75%      76.950000
# max      95.400000
# dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Boxplots

# %% [markdown]
# ![boxplot-1-1024x664.png](data:image/png;base64,...)

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.set_title('Boxplot das peças fabricadas')
ax.boxplot(dados);
ax.set_xlabel('dados');

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
plt.hist(dados,edgecolor='k')
Titulo='Histograma'
RotuloY='Frequencia de ocorrência das peças'
RotuloX='Classes'
ax.set_title(Titulo)
ax.set_ylabel(RotuloY)
ax.set_xlabel(RotuloX)

plt.show()

# %% [markdown]
# ## Coeficiente de Correlação de Pearson

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![correlacao.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Foram coletados os dados de horas de estudo e as notas obtidas por um grupo de alunos. Qual a correlação entre essas variávies?

# %%
#matriz com os dados de horas de estudo
horasEstudo=[20,12,14,15,18,9,5,4,8,13,14,15,19,18,12,11,10,15,17,20]
#matriz com os dados notas
Notas=[9.5,2.5,3.6,6.7,5.2,1,0,1.5,2,3,3.5,4.5,8.5,7.5,5,4,3,5,6.5,10]

#### gráfico
#plt.figure(figsize=(12, 8))
plt.title('Correlação entre horas de estudo e notas')
plt.xlabel('Horas de Estudo')
plt.ylabel('Notas')
#correlação que será analisada
plt.scatter(horasEstudo, Notas)
plt.show()

# %%
r = np.corrcoef(horasEstudo,Notas)

# %%
r
# Out:
# array([[1.        , 0.90348787],
#        [0.90348787, 1.        ]])

# %%
corr,_= pearsonr(horasEstudo,Notas) 
corr
# Out:
# 0.9034878716397753

# %% [markdown]
# https://www.kaggle.com/
